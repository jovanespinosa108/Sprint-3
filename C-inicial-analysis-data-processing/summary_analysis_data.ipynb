# %% [markdown]
# SUMMARY DATA WRANGLING
#
# Durante este sprint has aprendido muchas técnicas muy útiles; y pronto te mostraremos el conocimiento práctico en el proyecto.
#
# Esta es una recapitulación rápida de lo que has aprendido:
#
# Puedes renombrar columnas en un DataFrame utilizando rename(), identificar valores ausentes con isna() e isnull() y llenar o eliminar valores ausentes cuando se requiera. Por ejemplo:
#
# import pandas as pd
#
# #Renombrar columnas en el DataFrame
# df = df.rename(columns={'old_name': 'new_name'})
#
# #Identificar valores ausentes
# missing_values = df.isna().sum()
#
# #Llenar valores ausentes con 0
# df['my_column'].fillna(0, inplace=True)
#
# También ya aprendiste a trabajar con los duplicados detectándolos y eliminándolos y exploraste el uso de unique() y nunique() para manejar distintos datos
#
# #Comprobar si hay duplicados
# duplicates_count = df.duplicated().sum()
#
# #Eliminar duplicados
# df = df.drop_duplicates()
#
# #Recuperar valores únicos y su recuento
# unique_values = df['my_column'].unique()
# unique_count = df['my_column'].nunique()
#
# Por último, ahora puedes agrupar datos de manera efectiva utilizando groupby() para separar, aplicar funciones y combinar datos:
#
# #Agrupar datos por columna y calcular la suma
# grouped_df = df.groupby('category_column')['value_column'].sum()
#
# Nos entusiasma mucho ver lo que has progresado. Pero por ahora, puedes refrescar tu memoria con algunos ejercicios.
#
# Práctica guiada
#
# Pregunta
#
# Cuestionario 1
# ¿Cómo se puede usar el método rename() para cambiar el nombre de las columnas? Selecciona todas las opciones que correspondan:
#
# Elige tantas como quieras
# *df = df.rename(columns={'old name':'new name'})
# ¡Sí, esta es una de las formas posibles!
#
# *df.rename(columns={'old name':'new name'}, inplace=True)
# Definitivamente esto es algo que funcionará.
#
# df = df.rename(columns=['old name', 'new name'])
#
# *Usar un bucle for y métodos de string.
# ¡Esto también es correcto!
#
# ¡Perfecto!
#
# Pregunta
#
# Cuestionario 2
# ¿Cómo comprobarías el número de valores ausentes en un conjunto de datos? Selecciona todas las opciones que correspondan:
#
# Elige tantas como quieras
# *df.isna().sum()
# ¡Sí, esta es una de las formas posibles!
#
# *df.isnull().sum()
# ¡Exacto!
#
# Desplazarme por la tabla y buscar valores NaN.
#
# ¡Lo has entendido bien!
#
# Pregunta
#
# Cuestionario 3
# Para eliminar todos los valores NaN, existen varios enfoques. Estas son algunas opciones:
#
# Elige tantas como quieras
# *df['my column'].fillna(0, inplace=True)
# Este enfoque reemplaza todos los valores NaN en 'my column' por ceros.
#
# *df['my column'] = df['my column'].fillna(0)
# Este enfoque reemplaza todos los valores NaN en 'my column' por ceros y reemplaza la columna anterior por la nueva.
#
# df['my column'] = df['my column'].drop_duplicates()
#
# *df['my column'] = df['my column'].dropna()
# Este enfoque elimina todas las filas con NaN. Es una opción válida en algunos casos.
#
# ¡Bien hecho!
#
# Pregunta
#
# Cuestionario 4
# ¿Cómo podemos buscar datos duplicados en un DataFrame y ver cuántos hay?
#
# *df.duplicated().sum()
# Este método nos da el número de duplicados en un DataFrame. Para eliminar duplicados, debes usar el método drop_duplicates().
#
# df.duplicated().count()
#
# df.duplicated()
#
# ¡Perfecto!
#
# Pregunta
#
# Cuestionario 5
# ¿Qué es verdadero sobre los métodos unique() y nunique()?
#
# Elige tantas como quieras
#
# *No devuelven lo mismo.
# Esta afirmación es correcta. Hay una diferencia entre los dos métodos.
#
# *unique() devuelve los valores únicos, mientras que nunique() devuelve el número de valores únicos.
# Esta afirmación es correcta.
#
# unique() devuelve los valores únicos, mientras que nunique() devuelve los valores que no son únicos.
#
# nunique() devuelve el número de valores únicos, mientras que unique() devuelve los valores únicos.
#
# ¡Excelente trabajo!
#
# Pregunta
#
# Cuestionario 6
# ¿Qué etapas de la agrupación existen?
#
# Elige tantas como quieras
#
# *Dividir
# La primera etapa en la que aplicamos el método groupby() pasando la columna que queremos usar para la agrupación.
#
# Analizar
#
# *Aplicar
# La segunda etapa. Aquí aplicamos métodos a los grupos, por ejemplo, count() o sum().
#
# Separar
#
# *Combinar
# La última etapa en la que especificamos la columna de nuestro interés y almacenamos el resultado en una nueva estructura de datos, como un DataFrame.
#
# ¡Bien hecho!
#
# Siguientes pasos
#
# Luchaste y ganaste tu primera batalla contra los problemas más comunes con los datos: los valores ausentes y los datos duplicados. ¡Bien hecho! Saber cómo trabajar con valores ausentes y duplicados, así como con agrupación y ordenamiento, te ayudará mucho en tus futuros análisis.
#
# Ahora eres capaz de:
#
# Usar el método rename() para cambiar el nombre de las columnas.
#
# Utilizar isnull(), fillna() y dropna() para identificar, llenar y eliminar valores ausentes.
#
# Utilizar los métodos duplicated(), reset_index(), unique() y nunique() para trabajar con duplicados.
#
# Explica qué es la agrupación, las etapas de la agrupación y cómo agrupar en pandas.
#
# Ordena los datos usando el método sort_values().
#
# ![manipulacion_datos.png](attachment:manipulacion_datos.png)
